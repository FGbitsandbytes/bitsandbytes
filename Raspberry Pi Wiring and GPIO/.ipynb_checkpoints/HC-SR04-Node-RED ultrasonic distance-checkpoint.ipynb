# %% [markdown]
# # Node-RED ultrasonic distance
#
# [written in markdown](https://daringfireball.net/projects/markdown/syntax)
# [*source*](https://t3alliance.org/lessons/rpi-node-red-sonic-sensor-hc-sr04/)
#
# Goal:
# Read distance measurements from the sonic sensor within Node-Red
#
# What You Will Learn:
# How the ultrasonic sensor is wired and how it can be programmed.
#
# ![HC-SR04-Ultrasonic-Wiring-Diagram.jpg](attachment:ee6bad96-52a6-451f-b369-a419681a8bec.jpg)

# %% [markdown]
# ## Parts List
#
# ![HC-SR04-Wires-F-F-445x600.jpeg](attachment:4ae446c5-38f5-41c9-8ebe-5128cc1e9950.jpeg)
# ![HC-SR04-Ultrasonic-Sensor-600x413.jpg](attachment:a01394cb-4dfa-4a01-aff4-3a14840d9881.jpg)

# %% [markdown]
# ## What is an Ultrasonic Distance Sensor?
# It is a sensor that works based on the principles of echo location.  The sensor is able to emit ultrasonic pulses and read ultrasonic pulses, using this timing information along with the speed of sound and some math we can extrapolate distance to the surface the pulses have reflected against.
#
# ![HC-SR04-distanceformula.png](attachment:5d587452-56aa-4093-ae65-7fc3671c7a20.png)
#
#
# Thankfully the node we will be using will take care of the math for us :).

# %% [markdown]
# ![HC-SR04-Ultrasonic-Wiring-Diagram-768x625.jpg](attachment:5df4ca15-d8fa-4e5e-b94e-6da5907a826a.jpg)
#
# ### Wiring
#
# - VCC   -> 5V
# - Trig   -> PIN16 #23
# - Echo -> PIN18 #24
# - GND -> GND
#
# *For this sensor you MUST use the same pins as shown for Trig and Echo – it will not work with any other pins.*

# %% [markdown]
# ## Setting up Node-Red
# Start Node-Red and navigate to [127.0.0.1:1880](127.0.0.1:1880) using the web browser. Drag the “rpi srf” node and a “debug” node into the flow area.
#
# ![HC-SR04-Selection_288.png](attachment:21087762-77e5-4102-93db-a7514f602e45.png)
#
# Double click the “rpi srf” node to open its configuration settings.  Set Pins to “16,18” (which corespond to GPIO 23,24).  The programmer of this node decided that it was better to use the Raspberry Pi’s board pinout rather than the BCM standard, [this web page](https://pinout.xyz/) shows both.
#
# ![HC-SR04-Selection_290.png](attachment:7221e1ae-69b8-4694-84e8-7d0b677e6163.png)
#
# Next, open the “debug” nodes configuration settings.  Check the debug window and node status options.  This will display the last sent message beneath the debug node.
#
# ![HC-SR04-Selection_293.png](attachment:ee1a9a54-6680-4613-8b18-edd34d97f070.png)
#
# Link the nodes together and deploy the flow.
#
# ![HC-SR04-Selection_294.png](attachment:ec3f39c3-6019-4643-a518-d6b71bca44d8.png)
#
# ![HC-SR24-Selection_121.png](attachment:782334e7-b623-4ce4-9117-005e784d7df9.png)
#
# If everything has gone together properly, you should get numbers appearing below the “debug” node.  These are distance measurements in centimeters, you can change the frequency of the measurements within the “rpi srf” node or see the entire measurement history in the debug tab.
